# %% [markdown]
# <a href="https://colab.research.google.com/github/iryna-savchuk/CI4O_project/blob/catiaparrinha/CIFO_Project_y_hot_encoded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
# Append Charles Library, we can do this by cloning the gitbug
# !git clone https://github.com/iryna-savchuk/CI4O_project.git

#import sys
#sys.path.append('/content/CI4O_project')

# %%
# Append Charles Library
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/CIFO_Project')

# %%
# Import charles library
from charles.charles import Population, Individual
from charles.selection import tournament_sel, fps
from charles.crossover import cycle_xo, pmx, arithmetic_xo
from charles.mutation import swap_mutation, inversion_mutation

# %%
# Import others libraries
from copy import deepcopy
import numpy as np
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
from keras.utils import np_utils

# %% [markdown]
# # Importig and preprocessing data

# %%
# Import data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Reshape and normalize the input images
train_images = train_images.reshape(-1, 784) / 255.0
test_images = test_images.reshape(-1, 784) / 255.0

# Preprocess class labels
train_labels = np_utils.to_categorical(train_labels, 10)
test_labels = np_utils.to_categorical(test_labels, 10)

# %% [markdown]
# # Define Model and Fitness Function

# %%
#Define the model and fitness function:

def get_fitness(self):
    # Defining the architecture of a neural network
    nn = keras.Sequential([
        layers.Dense(512, activation="relu", input_shape=(784,)),
        layers.Dense(10, activation="softmax")
    ])

    # Setting the weights of the model
    nn.set_weights(self.representation)

    # Compiling the model
    nn.compile(optimizer="Adam",
               loss="categorical_crossentropy",
               metrics=["accuracy"])
    # Train model
    nn.fit(train_images, train_labels, epochs=1, verbose=0)

    test_loss, test_acc = nn.evaluate(test_images, test_labels)

    return test_loss

# %%
# Monkey patching
Individual.get_fitness = get_fitness

# %% [markdown]
# # Running the models

# %% [markdown]
# ## 1. Arithmetic Cross Over

# %% [markdown]
# ## Tournament Size = 4

# %% [markdown]
# ### Swap_mutation with xo_prob 80% and mut_prob 20%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=swap_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.2,
               xo_prob=0.8,
               elitism=True,
               tourn_size=4)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
swap_mean_4_80_20 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
swap_median_4_80_20 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Out:
# Running GA iteration: 1
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.5008 - accuracy: 0.8469
# Gen 1, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.5874024629592896
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.7207 - accuracy: 0.8898
# Gen 2, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.4260494709014893
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9116 - accuracy: 0.8660
# Gen 3, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.250519871711731
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.7716 - accuracy: 0.8748
# Gen 4, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.250519871711731
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9331 - accuracy: 0.8618
# Gen 5, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.250519871711731
#
# ...

# %% [markdown]
# ### Swap_mutation with xo_prob 95% and mut_prob 5%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=swap_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.05,
               xo_prob=0.95,
               elitism=True,
               tourn_size=4)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
swap_mean_4_95_5 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
swap_median_4_95_5 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Out:
# Running GA iteration: 1
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 4.1667 - accuracy: 0.8021
# Gen 1, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.775652289390564
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.3642 - accuracy: 0.8887
# Gen 2, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.3348015546798706
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.4610 - accuracy: 0.8221
# Gen 3, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.3348015546798706
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 3.1191 - accuracy: 0.8257
# Gen 4, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.3348015546798706
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9252 - accuracy: 0.8578
# Gen 5, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.3348015546798706
#
# ...

# %% [markdown]
# ### Swap_mutation with xo_prob 20% and mut_prob 80%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=swap_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.8,
               xo_prob=0.2,
               elitism=True,
               tourn_size=4)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
swap_mean_4_20_80 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
swap_median_4_20_80 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Out:
# Running GA iteration: 1
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 3.1398 - accuracy: 0.8486
# Gen 1, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6990770101547241
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.1461 - accuracy: 0.8866
# Gen 2, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6990770101547241
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.7333 - accuracy: 0.8824
# Gen 3, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6990770101547241
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9416 - accuracy: 0.8789
# Gen 4, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6990770101547241
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.4154 - accuracy: 0.8702
# Gen 5, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6990770101547241
# ...

# %% [markdown]
# #### Average/Median Best Fitness

# %%
arithmetic_xo_swap_4 = {
    'swap_average_4_80_20': swap_mean_4_80_20,
    'swap_average_4_95_5': swap_mean_4_95_5,
    'swap_average_4_20_80': swap_mean_4_20_80,
    'swap_median_4_80_20': swap_median_4_80_20,
    'swap_median_4_95_5': swap_median_4_95_5,
    'swap_median_4_20_80': swap_median_4_20_80
}

df_arithmetic_xo_swap_4 = pd.DataFrame(arithmetic_xo_swap_4)
df_arithmetic_xo_swap_4.to_csv('/content/gdrive/MyDrive/CIFO_Project/df_arithmetic_xo_swap_4.csv', index=False)
print(df_arithmetic_xo_swap_4)
# Out:
#    swap_average_4_80_20  swap_average_4_95_5  swap_average_4_20_80  \
# 0              1.697929             1.781680              1.815008
# 1              1.523633             1.585601              1.739942
# 2              1.482737             1.535292              1.688300
# 3              1.462328             1.480230              1.688169
# 4              1.453145             1.436584              1.644416
# 5              1.437909             1.436584              1.609037
# 6              1.418232             1.410458              1.606333
# 7              1.354786             1.409162              1.581036
# 8              1.346712             1.409162              1.576013
# 9              1.339200             1.404822              1.576013
#
#    swap_median_4_80_20  swap_median_4_95_5  swap_median_4_20_80
# 0             1.674972            1.774702             1.767288
# 1             1.526981            1.551355             1.754436
# ...

# %%
df_arithmetic_xo_swap_4.describe()
# Out:
#        swap_average_4_80_20  swap_average_4_95_5  swap_average_4_20_80  \
# count             10.000000            10.000000             10.000000
# mean               1.451661             1.488958              1.652427
# std                0.106073             0.119588              0.079932
# min                1.339200             1.404822              1.576013
# 25%                1.370648             1.409486              1.587360
# 50%                1.445527             1.436584              1.626726
# 75%                1.477635             1.521526              1.688267
# max                1.697929             1.781680              1.815008
#
#        swap_median_4_80_20  swap_median_4_95_5  swap_median_4_20_80
# count            10.000000           10.000000            10.000000
# mean              1.454916            1.475504             1.681945
# std               0.093770            0.119994             0.071921
# ...

# %% [markdown]
# ### Inversion_mutation with xo_prob 80% and mut_prob 20%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=inversion_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.2,
               xo_prob=0.8,
               elitism=True,
               tourn_size=4)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
inversion_mean_4_80_20 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
inversion_median_4_80_20 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Out:
# Running GA iteration: 1
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 3.0653 - accuracy: 0.8474
# Gen 1, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.8453668355941772
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.3721 - accuracy: 0.8736
# Gen 2, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.564738154411316
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.6353 - accuracy: 0.9099
# Gen 3, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.564738154411316
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4205 - accuracy: 0.9045
# Gen 4, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.4205007553100586
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.8227 - accuracy: 0.8670
# Gen 5, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.4205007553100586
#
# ...

# %% [markdown]
# ### Inversion_mutation with xo_prob 95% and mut_prob 5%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=inversion_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.05,
               xo_prob=0.95,
               elitism=True,
               tourn_size=4)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
inversion_mean_4_95_5 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
inversion_median_4_95_5 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Out:
# Running GA iteration: 1
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.7493 - accuracy: 0.8571
# Gen 1, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.8727113008499146
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.4911 - accuracy: 0.8458
# Gen 2, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6475142240524292
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.6219 - accuracy: 0.8783
# Gen 3, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.621944546699524
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.7328 - accuracy: 0.8112
# Gen 4, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.4994518756866455
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.7137 - accuracy: 0.8687
# Gen 5, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.4404010772705078
#
# ...

# %% [markdown]
# ### Inversion_mutation with xo_prob 20% and mut_prob 80%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=inversion_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.8,
               xo_prob=0.2,
               elitism=True,
               tourn_size=4)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
inversion_mean_4_20_80 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
inversion_median_4_20_80 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Out:
# Running GA iteration: 1
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.8114 - accuracy: 0.8555
# Gen 1, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6140621900558472
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 3.2359 - accuracy: 0.8194
# Gen 2, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6140621900558472
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.2511 - accuracy: 0.8841
# Gen 3, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6140621900558472
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.8008 - accuracy: 0.8968
# Gen 4, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6140621900558472
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 4.2271 - accuracy: 0.8326
# Gen 5, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6140621900558472
# ...

# %% [markdown]
# #### Average/Median Best Fitness

# %%
arithmetic_xo_inversion_4 = {
    'inversion_average_4_80_20': inversion_mean_4_80_20,
    'inversion_average_4_95_5': inversion_mean_4_95_5,
    'inversion_average_4_20_80': inversion_mean_4_20_80,
    'inversion_median_4_80_20': inversion_median_4_80_20,
    'inversion_median_4_95_5': inversion_median_4_95_5,
    'inversion_median_4_20_80': inversion_median_4_20_80
}

df_arithmetic_xo_inversion_4 = pd.DataFrame(arithmetic_xo_inversion_4)
df_arithmetic_xo_inversion_4.to_csv('/content/gdrive/MyDrive/CIFO_Project/df_arithmetic_xo_inversion_4.csv', index=False)
print(df_arithmetic_xo_inversion_4)
# Out:
#    inversion_average_4_80_20  inversion_average_4_95_5  \
# 0                   1.729449                  1.773160
# 1                   1.591487                  1.665733
# 2                   1.543662                  1.641299
# 3                   1.426442                  1.593287
# 4                   1.390775                  1.526115
# 5                   1.378208                  1.502836
# 6                   1.359850                  1.485216
# 7                   1.355186                  1.464695
# 8                   1.339874                  1.429737
# 9                   1.320617                  1.424862
#
#    inversion_average_4_20_80  inversion_median_4_80_20  \
# 0                   1.836581                  1.769763
# 1                   1.745897                  1.588819
# 2                   1.711567                  1.544968
# 3                   1.711567                  1.406987
# 4                   1.657593                  1.392103
# ...

# %%
df_arithmetic_xo_inversion_4.describe()
# Out:
#        inversion_average_4_80_20  inversion_average_4_95_5  \
# count                  10.000000                 10.000000
# mean                    1.443555                  1.550694
# std                     0.134027                  0.114402
# min                     1.320617                  1.424862
# 25%                     1.356352                  1.469826
# 50%                     1.384491                  1.514475
# 75%                     1.514357                  1.629296
# max                     1.729449                  1.773160
#
#        inversion_average_4_20_80  inversion_median_4_80_20  \
# count                  10.000000                 10.000000
# mean                    1.672505                  1.447398
# std                     0.079129                  0.144299
# min                     1.577745                  1.305776
# 25%                     1.619523                  1.376455
# 50%                     1.648707                  1.392103
# ...

# %% [markdown]
# ## Tournament Size = 10

# %% [markdown]
# ### Swap_mutation with xo_prob 80% and mut_prob 20%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=swap_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.2,
               xo_prob=0.8,
               elitism=True,
               tourn_size=10)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
swap_mean_10_80_20 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
swap_median_10_80_20 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Out:
# Running GA iteration: 1
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 3.1917 - accuracy: 0.8236
# Gen 1, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 2.1666524410247803
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 3.2890 - accuracy: 0.8451
# Gen 2, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 2.0038375854492188
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.8414 - accuracy: 0.8633
# Gen 3, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 2.0038375854492188
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.9450 - accuracy: 0.8341
# Gen 4, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 2.0038375854492188
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 3.3709 - accuracy: 0.8374
# Gen 5, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.667382836341858
#
# ...

# %% [markdown]
# ### Swap_mutation with xo_prob 95% and mut_prob 5%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=swap_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.05,
               xo_prob=0.95,
               elitism=True,
               tourn_size=10)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
swap_mean_10_95_5 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
swap_median_10_95_5 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Out:
# Running GA iteration: 1
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.5606 - accuracy: 0.8635
# Gen 1, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6623889207839966
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9936 - accuracy: 0.8818
# Gen 2, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6623889207839966
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9867 - accuracy: 0.8752
# Gen 3, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6623889207839966
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.5802 - accuracy: 0.8325
# Gen 4, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6623889207839966
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9965 - accuracy: 0.8698
# Gen 5, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.63388192653656
#
# ...

# %% [markdown]
# ### Swap_mutation with xo_prob 20% and mut_prob 80%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=swap_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.8,
               xo_prob=0.2,
               elitism=True,
               tourn_size=10)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
swap_mean_10_20_80 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
swap_median_10_20_80 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Out:
# Running GA iteration: 1
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0404 - accuracy: 0.8902
# Gen 1, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6197553873062134
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 3.0889 - accuracy: 0.8367
# Gen 2, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6197553873062134
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0533 - accuracy: 0.8902
# Gen 3, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6197553873062134
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.7595 - accuracy: 0.8666
# Gen 4, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6197553873062134
#
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 3.2449 - accuracy: 0.8254
# Gen 5, Best Individual: Individual:  (784, 512) (512,) (512, 10) (10,); Fitness: 1.6197553873062134
# ...

# %% [markdown]
# #### Average/Median Best Fitness

# %%
arithmetic_xo_swap_10 = {
    'swap_average_10_80_20': swap_mean_10_80_20,
    'swap_average_10_95_5': swap_mean_10_95_5,
    'swap_average_10_20_80': swap_mean_10_20_80,
    'swap_median_10_80_20': swap_median_10_80_20,
    'swap_median_10_95_5': swap_median_10_95_5,
    'swap_median_10_20_80': swap_median_10_20_80
}

df_arithmetic_xo_swap_10 = pd.DataFrame(arithmetic_xo_swap_10)
df_arithmetic_xo_swap_10.to_csv('/content/gdrive/MyDrive/CIFO_Project/df_arithmetic_xo_swap_10.csv', index=False)
print(df_arithmetic_xo_swap_10)
# Out:
#    swap_average_10_80_20  swap_average_10_95_5  swap_average_10_20_80  \
# 0               1.737676              1.655087               1.862873
# 1               1.630842              1.591225               1.779977
# 2               1.568334              1.548655               1.758263
# 3               1.541815              1.520399               1.726172
# 4               1.487570              1.475733               1.713064
# 5               1.479020              1.441925               1.701798
# 6               1.464954              1.441925               1.686853
# 7               1.459593              1.441746               1.679339
# 8               1.459593              1.436548               1.679339
# 9               1.445374              1.432381               1.677203
#
#    swap_median_10_80_20  swap_median_10_95_5  swap_median_10_20_80
# 0              1.723450             1.672828              1.885003
# ...

# %%
df_arithmetic_xo_swap_10.describe()
# Out:
#        swap_average_10_80_20  swap_average_10_95_5  swap_average_10_20_80  \
# count              10.000000             10.000000              10.000000
# mean                1.527477              1.498562               1.726488
# std                 0.094604              0.077791               0.059355
# min                 1.445374              1.432381               1.677203
# 25%                 1.460933              1.441791               1.681217
# 50%                 1.483295              1.458829               1.707431
# 75%                 1.561704              1.541591               1.750240
# max                 1.737676              1.655087               1.862873
#
#        swap_median_10_80_20  swap_median_10_95_5  swap_median_10_20_80
# count             10.000000            10.000000             10.000000
# mean               1.499040             1.492044              1.744238
# std                0.093746             0.086580              0.067459
# ...

# %% [markdown]
# ### Inversion_mutation with xo_prob 80% and mut_prob 20%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=inversion_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.2,
               xo_prob=0.8,
               elitism=True,
               tourn_size=10)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
inversion_mean_10_80_20 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
inversion_median_10_80_20 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]

# %% [markdown]
# ### Inversion_mutation with xo_prob 95% and mut_prob 5%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=inversion_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.05,
               xo_prob=0.95,
               elitism=True,
               tourn_size=10)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
inversion_mean_10_95_5 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
inversion_median_10_95_5 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]

# %% [markdown]
# ### Inversion_mutation with xo_prob 80% and mut_prob 20%

# %%
all_runs_best_fitness = []

for i in range(10):
    print(f"Running GA iteration: {i + 1}")
    # Create a population
    pop = Population(size=10, optim='min')
    # Reset best_fitness_list for each run
    best_fitness_list = []
    # Train the population
    pop.evolve(gens=10,
               select=tournament_sel,
               mutate=inversion_mutation,
               crossover=arithmetic_xo,
               mut_prob=0.8,
               xo_prob=0.2,
               elitism=True,
               tourn_size=10)
    all_runs_best_fitness.append(pop.best_fitnesses)

# Calculate the mean fitness for each generation across all runs
# Average Best Fitness
inversion_mean_10_20_80 = [np.mean([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]
# Median Best Fitness
inversion_median_10_20_80 = [np.median([run[i] for run in all_runs_best_fitness]) for i in range(len(all_runs_best_fitness[0]))]

# %% [markdown]
# #### Average/Median Best Fitness

# %%
arithmetic_xo_inversion_10 = {
    'inversion_average_10_80_20': inversion_mean_10_80_20,
    'inversion_average_10_95_5': inversion_mean_10_95_5,
    'inversion_average_10_20_80': inversion_mean_10_20_80,
    'inversion_median_10_80_20': inversion_median_10_80_20,
    'inversion_median_10_95_5': inversion_median_10_95_5,
    'inversion_median_10_20_80': inversion_median_10_20_80
}

df_arithmetic_xo_inversion_10 = pd.DataFrame(arithmetic_xo_inversion_10)
df_arithmetic_xo_inversion_10.to_csv('/content/gdrive/MyDrive/CIFO_Project/df_arithmetic_xo_inversion_10.csv', index=False)
print(df_arithmetic_xo_inversion_10)

# %%
df_arithmetic_xo_inversion_10.describe()

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Based on the Average

# %% [markdown]
# ## Based on the Median
